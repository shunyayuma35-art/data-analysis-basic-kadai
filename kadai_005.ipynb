# %% [markdown]
# <a href="https://colab.research.google.com/github/shunyayuma35-art/data-analysis-basic-kadai/blob/main/kadai_005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# サブプロットを2行3列で作成
fig, axes = plt.subplots(2, 3, tight_layout=True)

# ① 折れ線グラフ
y0 = [1, 2, -5, 2]
axes[0, 0].plot(y0)
axes[0, 0].set_title("Line plot")

# ② sin関数
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
axes[0, 1].plot(x, y1)
axes[0, 1].set_title("Sin curve")

# ③ ヒストグラム
data = np.random.normal(20, 5, 1000)
axes[0, 2].hist(data)
axes[0, 2].set_title("Histogram")

# ④ 散布図
x2 = np.random.rand(50)
y2 = np.random.rand(50)
axes[1, 0].scatter(x2, y2)
axes[1, 0].set_title("Scatter")

# 残り2枠は空でOK

plt.show()
